# %%
import pandas as pd

s = pd.Series([1,2,3], index = ["First","Second","Third"])
print(f"The item index 1 is {s.iloc[1]}")
print(f"The item with the label Third is {s['Third']}")
# Out:
# The item index 1 is 2
# The item with the label Third is 3

# %%
d = pd.DataFrame([1,2,3], [4,5,6])
d.index = ['a','b','c']
d

d = pd.DataFrame([[1,2,3],[4,5,6]], 
                index = ['a','b'],
                columns = ['One','Two','Three'])

d
# Out:
#    One  Two  Three
# a    1    2      3
# b    4    5      6

# %%
#data = pd.read_csv('team.csv')
#data.head()
#data.tail()
#data.describe()
#data.columns
#data.index

# %%
#data['Number of Socks']
#data.Age

#data[0:2]

#data.loc[0:3, ["Number of Socks", "Occupation"]]

# %%
#data
#data[0:3]
#data.Age
#data['Number of Socks'].mean()

# %%
data = pd.read_csv('melb_data.csv')
#data.columns
#round(data['Rooms'].mean())
#round(data['Price'].mean())

# %%
data['BuildingArea']
data = data.dropna(axis = 0)
data['BuildingArea']
# Out:
# 1         79.00
# 2        150.00
# 4        142.00
# 6        210.00
# 7        107.00
#           ...
# 12205    149.00
# 12206    115.00
# 12207     35.64
# 12209     61.60
# 12212    388.50
# Name: BuildingArea, Length: 6196, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor

y = data.Price
features = ['Rooms', 'Bathroom','Landsize', 'Lattitude','Longtitude']
x = data[features]

melbourne_model = DecisionTreeRegressor(random_state = 1)

melbourne_model.fit(x,y)
print(f"Making predictions for the next five houses: ")
x.head()
print("The predictions are")
print(melbourne_model.predict(x.head()))
y.head()
# Out:
# Making predictions for the next five houses:
# The predictions are
# [1035000. 1465000. 1600000. 1876000. 1636000.]
# 1    1035000.0
# 2    1465000.0
# 4    1600000.0
# 6    1876000.0
# 7    1636000.0
# Name: Price, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error

predicted_home_prices  = melbourne_model.predict(x)
mean_absolute_error(y, predicted_home_prices)
# Out:
# 1115.7467183128902

# %%
from sklearn.model_selection import train_test_split


train_x, val_x, train_y, val_y = train_test_split(x, y, random_state = 0)
melbourne_model = DecisionTreeRegressor()
melbourne_model.fit(train_x, train_y)

val_predictions = melbourne_model.predict(val_x)
train_predictions = melbourne_model.predict(train_x)
print(round(mean_absolute_error(val_y, val_predictions)))
print(round(mean_absolute_error(train_y, train_predictions)))
# Out:
# 274910
# 898
